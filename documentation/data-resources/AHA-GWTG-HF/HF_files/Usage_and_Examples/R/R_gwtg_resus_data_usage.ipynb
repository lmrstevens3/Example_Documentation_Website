# %% [markdown]
# <div style='padding:5px; border-bottom:0.25rem solid #f3f3f3; height:100px;'><img src='https://precision.heart.org/assets/images/aha-pmp-logo.png' alt='Drawing' style='width:135px; float:left;'><img src='https://precision.heart.org/sso/images/precision-medicine-platform-logo.png' alt='Drawing' style='width:140px; float:right;'></div>

# %% [markdown]
# <div style="font-size:32px; padding:5px;"><b>Loading and Summarizing GWTG Data in R</b></div>

# %% [markdown]
# <div style="font-size:22px; padding-bottom:10px; padding-top:20px; color:#6D6E71"><b>Laura Stevens, Remy Poudel, Raakhee Iyer</b></div>
# <div style="font-size:18px; font-style:italic; color:#6D6E71"><b>October 2020</b></div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction-and-Software" data-toc-modified-id="Introduction-and-Software-1"><span style="width: 50% ; color: #c10e21 ; border-bottom: 0.25rem solid #f3f3f3">Introduction and Software</span></a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Software" data-toc-modified-id="Software-1.0.1">Software</a></span></li><li><span><a href="#Using-R-Studio" data-toc-modified-id="Using-R-Studio-1.0.2">Using R Studio</a></span></li><li><span><a href="#Packages-Installation" data-toc-modified-id="Packages-Installation-1.0.3">Packages Installation</a></span></li><li><span><a href="#Libraries" data-toc-modified-id="Libraries-1.0.4">Libraries</a></span></li></ul></li></ul></li><li><span><a href="#Load-and-View-Data" data-toc-modified-id="Load-and-View-Data-2"><span style="width: 50% ; color: #c10e21 ; border-bottom: 0.25rem solid #f3f3f3">Load and View Data</span></a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Registry-File-Organization" data-toc-modified-id="Registry-File-Organization-2.0.1">Registry File Organization</a></span></li><li><span><a href="#File-Paths" data-toc-modified-id="File-Paths-2.0.2">File Paths</a></span></li><li><span><a href="#Loading-SAS-files-in-R" data-toc-modified-id="Loading-SAS-files-in-R-2.0.3">Loading SAS files in R</a></span></li><li><span><a href="#Viewing-the-data" data-toc-modified-id="Viewing-the-data-2.0.4">Viewing the data</a></span></li></ul></li></ul></li><li><span><a href="#Tables-and-Summary-Statistics" data-toc-modified-id="Tables-and-Summary-Statistics-3"><span style="width: 50% ; color: #c10e21 ; border-bottom: 0.25rem solid #f3f3f3">Tables and Summary Statistics</span></a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Tables-and-Frequencies" data-toc-modified-id="Tables-and-Frequencies-3.0.1">Tables and Frequencies</a></span></li><li><span><a href="#Summary-Statistics" data-toc-modified-id="Summary-Statistics-3.0.2">Summary Statistics</a></span></li></ul></li></ul></li><li><span><a href="#Need-Help?" data-toc-modified-id="Need-Help?-4"><span style="width: 50% ; color: #c10e21 ; border-bottom: 0.25rem solid #f3f3f3">Need Help?</span></a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Internet-access-in-a-PMP-workspace" data-toc-modified-id="Internet-access-in-a-PMP-workspace-4.0.1">Internet access in a PMP workspace</a></span></li><li><span><a href="#Billing,-Data,-or-Analysis-Questions?" data-toc-modified-id="Billing,-Data,-or-Analysis-Questions?-4.0.2">Billing, Data, or Analysis Questions?</a></span></li><li><span><a href="#Technical-Questions-or-Issues?" data-toc-modified-id="Technical-Questions-or-Issues?-4.0.3">Technical Questions or Issues?</a></span></li></ul></li></ul></li><li><span><a href="#References" data-toc-modified-id="References-5"><span style="width: 50% ; color: #c10e21 ; border-bottom: 0.25rem solid #f3f3f3">References</span></a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Helpful-R-Libraries/Packages" data-toc-modified-id="Helpful-R-Libraries/Packages-5.0.1">Helpful R Libraries/Packages</a></span></li><li><span><a href="#R-Tutorials" data-toc-modified-id="R-Tutorials-5.0.2">R Tutorials</a></span></li><li><span><a href="#Academic-Publications-and-Guidelines" data-toc-modified-id="Academic-Publications-and-Guidelines-5.0.3">Academic Publications and Guidelines</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # <span style='width:50%; color:#C10E21; border-bottom:0.25rem  solid #f3f3f3;'>Introduction and Software</span>

# %% [markdown]
# This notebook walks through loading, viewing and summarizing a GWTG dataset comprised of a sas7bdat data file and a sas7bcat formats file. The Tables and Summary statistics section provides a brief introduction for how to calculate frequencies and distribution statistics for categorical and continuous variables respectively.

# %% [markdown]
# ### Software
#
# This tutorial is completed using R and provides R studio examples. All packages and libraries used in this tutorial are listed and installed in the sections below. Packages used in this tutorial as well as additional packages that are useful for tabulating and summarizing data are listed in the [References Section](#References).
#
# ### Using R Studio
#    * As shown below, the username and password for R Studio is *rstudio* and *workspace* respectively. Passwords and log in information are provided upon starting a workspace as well as available in the ReadMe.ipynb in /mnt/workspace.
#    * This tutorial is accompanied with a R_covid19_cvd_data_usage.R File which can be opened and used in R Studio.
#
# <div>
# <img src="attachment:log_in_rstudio.png" width="300" style="float:left"/>
# </div>

# %% [markdown]
# ### Packages Installation
#
# The following packages are used for this tutorial. Packages only need to be installed once. After initial installation, the cell below can be skipped or commented out (using "#").

# %%
#package to load sas files
install.packages('haven')
# Out:
# Installing package into ‘/usr/lib64/R/library’
# (as ‘lib’ is unspecified)
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %% [markdown]
# ### Libraries
#
# Once all packages have been installed they can be used through the library() command. The code below loads all libraries for the tutorial

# %%
library(haven)

# %% [markdown]
# # <span style='width:50%; color:#C10E21; border-bottom:0.25rem  solid #f3f3f3;'>Load and View Data</span>

# %% [markdown]
# ### Registry File Organization
# The root directory path in the workspace is <code>/mnt/workspace</code>. This is the directory for the files listed under the Jupyter Home tab as well as the default working directory for Jupyter, JupyterLab, R Studio, and SAS Studio.
#
# The data, documentation, and usage files for each release of the registry are contained in separate folders within the <code>/mnt/workspace/GWTG/</code> directory and structured as follows:
#    * Each AHA GWTG <b>registry</b> has it's own folder with the GWTG directory (e.g.<code>Resuscitation</code>)
#    * The data and accompanying documentation are stored in a directory named with the <b>version number followed by year-month of the release for that version</b> (e.g. v1_2020-08).
#    * Each version for a registry release contains the following:
#        * A <code><b>data</b></code> folder with sas data and format files
#        * A <code><b>documentation</b></code> folder with necessary documentation including the data dictionary and coding manual.
#
# For a more in-depth introduction to the registry data files available in a PMP workspace, **check the [GWTG Resuscitation Registry Researcher Resource](https://precision.heart.org/documentation/AHA-GWTG-Resus/index.html)**. **This website is available through the "PMP Documentation" bookmark in the favorites bar above under the data resources menu.**

# %% [markdown]
# ### File Paths
# <b><span style="background-color:pink;">This notebook can be used to load any version of the registry data by changing the file paths created in the cell below.</span></b> The code in the next cell creates a file path based on the version of the registry for the dataset being loaded.
#
# <span style="color:#C10E21;"><b><i>NOTE:</b></i></span> ***If needed, change the version_release_date, dataset_folder and data_file names below to update the data loaded***

# %%
registry = "Resuscitation/"
version_release_date = "v3_2021-06/"
#The paste command below is merging all the variables to make a single file path.
data_directory =  paste0("/mnt/workspace/GWTG/", registry, version_release_date,  "data/")
dataset_folder="CPA Adult/"
data_file = paste0(data_directory, dataset_folder,'v3_2021_06_gwtg_resus_cpa_adult.sas7bdat')
formats_file = paste0(data_directory, dataset_folder, 'formats/v3_2021_06_gwtg_resus_formats.sas7bdat')

# %% [markdown]
# ***This notebook is currently set to load the following dataset.*** Change directory names set to the registry, release date, dataset_folder variables above to load different versions of the data.

# %%
data_file
formats_file
# Out:
# [1] "/mnt/workspace/GWTG/Resuscitation/v3_2021-06/distribution/data/CPA Adult/v3_2021_06_gwtg_resus_cpa_adult.sas7bdat"
# [1] "/mnt/workspace/GWTG/Resuscitation/v3_2021-06/distribution/data/CPA Adult/formats/v3_2021_06_gwtg_resus_formats.sas7bdat"

# %% [markdown]
# ### Loading SAS files in R
#
# **The code below will load both the data as well as the formats/coding for the variables in the data.** <span style="background-color:pink;">The code below stores the data in <b>df</b> dataframe, the definitions and formats for each variable are stored as column attributes in each variable column in the dataframe. The <b>formats</b> dataframe stores the coding information for each format available in the data.</span> The first 10 rows of both dataframes are shown below.
#
# ##### Mapping formats and coding
# To map the coding labels for a categorical variable in the data, use <code>attributes(&lt;data column&gt;)$format</code> to get the coding format for a variable look the format up using the FMTTNAME column in formats. An example is provided in the [Tables and Summary Statistics Section](#Tables-and-Frequencies)

# %%
df <- read_sas(data_file)
formats <- read_sas(formats_file)

# %% [markdown]
# ### Viewing the data

# %% [markdown]
# The following commands are helpful when viewing large datasets.
# * <code>head()</code> will show the first 6 rows (or the number of rows is passed to n). Similarly <code>tail()</code> will display the last 6 rows.
# * <code>colnames()</code> can be used to view the variable names (or field names) of the data.
# * <code>str()</code> will give an overview of the data type, label (description), and coding values.
#     * To view all metadata for a given variable, the <code>attributes()</code> command can be used (ex. <code>attributes(df$RACE)</code>).
#
# ***NOTE:*** *The <code>colnames()</code> and <code>str()</code> commands can be used on the entire dataset as well as a subset. Given the large size of the data, a subset used to limit the output displayed in the code cells below.*

# %%
head(df, n = 10) #set n = 10, to show 10 rows
# Out:
#    AGE_CPAY_NEW ADM_ID_FAN SITE_ID SITE_ID_FAN FORMVER COVIDDIAG COVIDVACC
# 1  57           4097749    32987   32987           NA  NA        NA
# 2  77           4097975    31192   31192           NA  NA        NA
# 3  61           4098327    57203   57203           NA  NA        NA
# 4  76           4102670    31192   31192       201106  NA        NA
# 5  76           4102670    31192   31192       201106  NA        NA
# 6  56           4103256    31192   31192           NA  NA        NA
# 7  66           4105730    31192   31192           NA  NA        NA
# 8  63           4106652    31192   31192           NA  NA        NA
# 9  66           4108234    31192   31192           NA  NA        NA
# 10 86           4108676    31192   31192           NA  NA        NA
#    COVIDVACCDT COVIDVACCDT_ND COVIDVACCDOC ⋯ DURATION_SEC_ROC DURATION_MIN_ROC
# 1  <NA>        NA             NA           ⋯     NA              NA
# 2  <NA>        NA             NA           ⋯  30840             514
# ...

# %%
head(formats, n = 10) #set n = 10, to show 10 rows
# Out:
#    FMTNAME             START            END
# 1  ACTIVECF                           1                1
# 2  ACTIVECF                           2                2
# 3  ACTIVECF                           3                3
# 4  ACTIVECF                           4                4
# 5  ACTIVECF                           5                5
# 6  ACTIVECF                           6                6
# 7  ACTIVECF                           7                7
# 8  ACTIVECOOLING5F                    1                1
# 9  ACTIVECOOLING5F                    2                2
# 10 ACTIVECOOLINGPROC5F                1                1
#    LABEL                                            MIN MAX DEFAULT LENGTH
# 1  1: Surface Cooling                               1   48  48      48
# 2  2: Cold IV Saline Bolus                          1   48  48      48
# 3  3: Intravascular device or catheter (continuous) 1   48  48      48
# ...

# %%
str(df[,c(1:3, 6:8, 10)]) #show structure of columns 1-3, 6-8, and 10
# Out:
# tibble [520,523 × 7] (S3: tbl_df/tbl/data.frame)
#  $ AGE_CPAY_NEW: chr [1:520523] "57" "77" "61" "76" ...
#  $ ADM_ID_FAN  : num [1:520523] 4097749 4097975 4098327 4102670 4102670 ...
#   ..- attr(*, "label")= chr "Admission ID for Analysis"
#  $ SITE_ID     : num [1:520523] 32987 31192 57203 31192 31192 ...
#   ..- attr(*, "label")= chr "Site/Facility/Hospital ID"
#   ..- attr(*, "format.sas")= chr "BEST12"
#  $ COVIDDIAG   : num [1:520523] NA NA NA NA NA NA NA NA NA NA ...
#   ..- attr(*, "format.sas")= chr "BEST12"
#  $ COVIDVACC   : num [1:520523] NA NA NA NA NA NA NA NA NA NA ...
#   ..- attr(*, "format.sas")= chr "BEST12"
#  $ COVIDVACCDT : Date[1:520523], format: NA NA ...
#  $ COVIDVACCDOC: num [1:520523] NA NA NA NA NA NA NA NA NA NA ...
#   ..- attr(*, "format.sas")= chr "BEST12"

# %%
colnames(df[, 100:105]) #display columns 100-105
# Out:
# [1] "IPB_NONE"  "IPB_AAR"   "IPB_SEDA"  "IPB_DIAL"  "IPB_ICD"   "IPB_ETCO2"

# %%
attributes(df$RACE) #display attributes of variable "RACE"
# Out:
# $label
# [1] "Race, as reported in PMT"
#
# $format.sas
# [1] "RACE"

# %% [markdown]
# # <span style='width:50%; color:#C10E21; border-bottom:0.25rem  solid #f3f3f3;'>Tables and Summary Statistics</span>

# %% [markdown]
# ### Tables and Frequencies

# %% [markdown]
# Getting the counts of one or multiple variables is easy in R with the table function. The **table()** function will create a set of counts. This function can be used to get counts of categorical variables in the data, as shown in the code below, which makes a table of the number of patients by the categories in the variable specified.
#
# * Tables can also be made for multiple variables. For example:
#     * <code>table(df$SEX, df$RACE, useNA = "ifany")</code>
# * The <code>prop.table()</code> function can be used to get a percentage of data for categorical variables. The <code>round()</code> function can be used to show the percentage with only 2 decimal places. For example:
#     * <code>round(prop.table(var_table)*100,2)</code>

# %%
table(df$RACE, useNA = "ifany")
# Out:
#      1      2      3      4      5      6      7   <NA>
# 344713 121159   9194   2649  35155   4533   1043   2077

# %% [markdown]
# ##### Mapping coding labels to a categorical variable.
# To map the coding labels, the <code>attributes(&lt;data column&gt;)$format</code> command can be used to look up coding in the formats dataframe. The code below uses <code>factor()</code> to convert a variable to a factor with the appropriate coding labels. <i><b>Note:</b> variables with missingness will have missing labels first, which should be removed or accounted for when mapping.</i>

# %%
#get coding for df variable METHDIAG
coding <- formats$LABEL[formats$FMTNAME == attributes(df$RACE)$format][c(0:7)]
#set variable typeas factor with coding labels
df$RACE <- factor(df$RACE, labels = coding)
#create a table with labels
table(df$RACE, useNA = "ifany") #useNA shows missing values if present
# Out:
#                  1:White                  2:Black                  3:Asian
#                   344713                   121159                     9194
#            4:AmerInd/Esk 5:Unable to Det/Unk/NotD                  6:Other
#                     2649                    35155                     4533
#          7:NatHaw/PacIsl                     <NA>
#                     1043                     2077

# %% [markdown]
# ### Summary Statistics
# The <code>summary()</code> command can be used to view distribution statistics for all variables in the data or for a single variable. The summary command will display frequencies of categories for categorical variables that are read in as factors or converted to factors.
#
# ***NOTE:*** <code>summary()</code> can be used on the entire dataset. Given the large size of the data, the command is called on a single variable below to limit the output displayed.*

# %%
summary(df$AGE_CPAY_NEW)
# Out:
#    Length     Class      Mode
#    520523 character character

# %%
summary(as.factor(df$RACE))
# Out:
#                  1:White                  2:Black                  3:Asian
#                   344713                   121159                     9194
#            4:AmerInd/Esk 5:Unable to Det/Unk/NotD                  6:Other
#                     2649                    35155                     4533
#          7:NatHaw/PacIsl                     NA's
#                     1043                     2077

# %% [markdown]
# # <span style='width:50%; color:#C10E21; border-bottom:0.25rem  solid #f3f3f3;'>Need Help?</span>
# ### Internet access in a PMP workspace
#    * Google and other useful programming sites including git and stack overflow are available in the workspace. Simply add a tab on by clicking the + on the blue, browser bar above.
#
#
# ###  Billing, Data, or Analysis Questions?
#    * If you have questions about your account, billing, the GWTG data, or would like to request analysis help from the AHA Data Science Team, please file a ticket with the data team by selecting [Contact Us](https://precision.heart.org/contact) on the PMP portal under the About tab.
#
#
# ### Technical Questions or Issues?
#    * If you are having technical trouble installing software or packages, using the workspace or software in the workspace, please file a ticket with support by selecting [technical support](https://precision.heart.org/technical-support) on the PMP portal under the About tab.

# %% [markdown]
# # <span style='width:50%; color:#C10E21; border-bottom:0.25rem  solid #f3f3f3;'>References</span>
# ###  Helpful R Libraries/Packages
#    * Loading SAS files in R
#         * [haven](https://haven.tidyverse.org/)
#    * Data Manipulation
#         * [dplyr](https://dplyr.tidyverse.org/)
#         * [tidyr](https://tidyr.tidyverse.org/)
#    * Tables and display
#         * [htmlTables](https://cran.r-project.org/web/packages/htmlTable/vignettes/general.html)
#         * [DT](https://rstudio.github.io/DT/)
#         * [tableone](http://rstudio-pubs-static.s3.amazonaws.com/13321_da314633db924dc78986a850813a50d5.html)
#    * Plotting and Graphs
#         * [plotly](https://plotly.com/r/)
#         * [ggplot2](https://ggplot2.tidyverse.org/)
#         * [ggfortify](https://www.rdocumentation.org/packages/ggfortify/versions/0.4.10)
#
# ### R Tutorials
#    * [Data Science with R](https://data-flair.training/blogs/r-tutorials-home/)
#    * [R bloggers](https://www.r-bloggers.com/how-to-learn-r-2/)
#
# ### Academic Publications and Guidelines
#    * [Descriptives Statistics Explanation](https://www.socialresearchmethods.net/kb/statdesc.php)
#    * [Reporting Descriptives in Clinical Studies](https://trialsjournal.biomedcentral.com/articles/10.1186/s13063-016-1189-4)

# %% [markdown]
# <div style='padding-top:5px; border-top:0.25rem solid #f3f3f3;  font-size:1.5rem; color:#6D6E71; text-align:center;  padding-left:5%; padding-right:15%'>Use of the AHA Get With The Guidelines  <span>&#174;</span> Datasets in the Precision Medicine Platform is a strategic initiative of the American Heart Association's Institute for Precision Cardiovascular Medicine. The Platform is supported by Hitachi Vantara and powered by Amazon Web Services.
#         <img src=https://www.hitachivantara.com/content/dam/public/en_us/images/sharing-graphic.jpg alt='Drawing' style='height:75px; margin-top:-5px;  float:center'>
#          <img src='https://a0.awsstatic.com/libra-css/images/logos/aws_logo_smile_1200x630.png'  alt='Drawing' style='height:75px; margin-top:-10px; float:center;'>
# </div>
